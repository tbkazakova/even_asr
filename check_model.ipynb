# %%
# %%capture
# !pip install datasets
# !pip install transformers
# !pip install torchaudio
# !pip install jiwer
# !pip install accelerate -U

# %%
import IPython.display as ipd
import numpy as np
import random
from datasets import ClassLabel
import pandas as pd
from IPython.display import display, HTML
import torch
from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union
from tqdm import tqdm

# %%
# %%capture
# !apt install git-lfs

# %%
from datasets import load_dataset, load_metric, Audio

# %%
dataset = load_dataset("tbkazakova/even_speech_hse", split='train')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Resolving data files:   0%|          | 0/130 [00:00<?, ?it/s]

# %%
even_hse = dataset

# %%
from transformers import AutoModelForCTC, Wav2Vec2BertProcessor

model = AutoModelForCTC.from_pretrained("tbkazakova/wav2vec-bert-2.0-even-pakendorf")
processor = Wav2Vec2BertProcessor.from_pretrained("tbkazakova/wav2vec-bert-2.0-even-pakendorf")
# Out:
# config.json:   0%|          | 0.00/1.91k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.42G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/231 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/30.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
import re
chars_to_remove_regex = '[,?.!-;:"“%‘”\'»\«\„\‐\–()=[]\\]'

def remove_special_characters(batch):
    # remove special characters
    batch["transcription"] = re.sub(chars_to_remove_regex, '', batch["transcription"]).strip().lower()
    return batch

# %%
def prepare_dataset(batch):
    audio = batch["audio"]
    batch["input_features"] = processor(audio["array"], sampling_rate=audio["sampling_rate"]).input_features[0]
    batch["input_length"] = len(batch["input_features"])
    batch["labels"] = processor(text=batch["transcription"]).input_ids
    return batch

# %%
even_hse = even_hse.map(remove_special_characters)
even_hse = even_hse.cast_column("audio", Audio(sampling_rate=16_000))
even_hse = even_hse.map(prepare_dataset, remove_columns=even_hse.column_names)
# Out:
# Map:   0%|          | 0/129 [00:00<?, ? examples/s]

# %%
wer_metric = load_metric("wer")
cer_metric = load_metric("cer")
# Out:
# <ipython-input-11-0dc5f81e0ca6>:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   wer_metric = load_metric("wer")
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for wer contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.2/metrics/wer/wer.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for cer contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.2/metrics/cer/cer.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(

# %%
input_dict = even_hse[0]

logits = model(torch.tensor(input_dict["input_features"]).unsqueeze(0)).logits

pred_ids = torch.argmax(logits, dim=-1)[0]

# %%
processor.decode(pred_ids)
# Out:
# 'би куӈарапчи эрэгэр бисиву этикэнну ми'

# %%
processor.decode(input_dict["labels"]).lower()
# Out:
# 'би куӈарыпч ырыгыр бишиву этыкэнуми'

# %%
predictions = []
references = []
for i in tqdm(range(len(even_hse))):
    input_dict = even_hse[i]
    logits = model(torch.tensor(input_dict["input_features"]).unsqueeze(0)).logits
    pred_ids = torch.argmax(logits, dim=-1)[0]
    predictions.append(processor.decode(pred_ids))
    references.append(processor.decode(input_dict["labels"]).lower())


wer = wer_metric.compute(predictions=predictions, references=references)
cer = cer_metric.compute(predictions=predictions, references=references)
# Out:
# 100%|██████████| 129/129 [09:56<00:00,  4.63s/it]

# %%
wer, cer
# Out:
# (0.8333333333333334, 0.2971014492753623)

# %%
pred_real = pd.DataFrame()
pred_real['pred'] = predictions
pred_real['real'] = references
pred_real.to_csv('pred_real_by_pakendorf.csv', index=False)

# %%
for i in range(len(predictions)):
    print(predictions[i])
    print(references[i])
    print()
# Out:
# би куӈарапчи эрэгэр бисиву этикэнну ми
# би куӈарыпч ырыгыр бишиву этыкэнуми
#
# тордула биддёттэм
# ордула бидётым
#
# нан рыбяткаддёттун гобдиддоттэн
# нан рыбалкадёту гобдыдёту
#
# хамгиддётту
# камгидёту
#
# нан
# нан
#
# тадук таӈнариву
# тадук таӈнариву
#
# интэрнатту биддыву
# интэрнату бидыву
#
# нан тадук таӈӈни ордыди мудакриди орриву нанда ортаки
# нан тадук таӈны одыдыв мудакриди уриву нанда ортэки
#
# эрэгэр орду биддин бичэвутту едэ нон армиятки ипкэн итэндув
# эрэр орду бидым бишиву тэдэ нан армиятки кулитын
#
# армиян одянниву тара нан тадук эмнивун нанда ортаки орриву
# армиянадяныву тар нан тадук эмниву нанда ортэки уриву
#
# туркурим туркурив бисин биӈэ дюлду
# туркуриву туркуриву бишин биӈа дюду
#
# эр грэкму биддёттэн у ноӈан же харавал укунюӈэрэтдн
# ырыгыр экму бидётын у ноӈан жэ коровал [unk]кэнюритын
#
# карававканни он
# корова укунён
#
# нан
# нан
#
# э
# так
#
# нан тиеда этыкэм к родыди атыкаӈниву
# нан тэдэ этыкэмкыр одыди атыкаӈниву
#
# иланмяр дюранӈанав одакан
# иланмэр дюр анӈынын одакан
#
# нан тик дёрмяв илу мин анӈаду сатыкав атыканун биддёттэ
# нан тык дёрмяр илан инт анӈыну атыкан атыканун бидётым
#
# тунӈан куӈаӈалбу дёр бэил илан асил
# тунӈан куӈанылбы дюр бэил илан ашыл
#
# таӈадётту адунда кулигэлдэн дёттэ
# таӈыдёту адынды кулигылдыдёту
#
# он исин ан
# оныши нан
#
# эдэи таӈну бугуски нёндиддётту околлов бэйчиддёттэ
# эдэйи таӈы бугышки нёндидёту олыв быйчидёту
#
# дёриду мэентэки оруддёттудэ
# дюриду мэентэки урыдь урыдёту
#
# дюнно он виддётту дал мувколатаддавр айчир аймакан усчиддавур
# дюгынон бидётуда му колутыдэвыр аич аймакын кушчидэвыр
#
# орал бэргэ бидэтэн
# орол бэргэ бидэтын
#
# нан тадук дискир де укчилиддэв
# нан тадук дыйышки ури уридёв укчэлэдыв
#
# нэлькэкэ укчэллоттэн тар
# нэлкэк укчэльотын тар
#
# нан урэкчэнту койчиддёттэ
# нан урэкчэнтык ойчидёту
#
# тт тара содикиднот эдэн бивэттэн
# тытэл одакиднот эдэн бивэтын
#
# дюллакакан
# гилакакан
#
# адэтэн илкан геккик ноӈарбатан оролба
# ыдытын илкан геки кикэ ноӈарбутын оралбы
#
# нан тугэриду коеччотту онка бидиӈи
# нан туганиду коячоты онкэ бидин
#
# имуннатар коечиддётту
# имана нан коячидёты
#
# нёчэлбу она нёча бисни тувту одакан
# нёчалбы онын нёча бишни тывт онакын
#
# тара
# тар
#
# эдэн талчис чалбукав тал
# эдэнун тяв тыс чалбукар тар
#
# так нёчали одни тар
# тат нёчал одни тар
#
# начт тик ялта тогэни бидин
# значит тыктэ ялта тугэни бидин
#
# нёоча ӈин ун
# нёчал энунын
#
# ойла иман ноллан тара
# коетли имынылын тар
#
# эчу тыкрэр
# эчэ тыкырэ
#
# ачачи мун ни эгден бидин
# значит имын эгден бидин
#
# эуту уту чэви бокочт чэви тар
# тывты чэвэ бокат чэвэ тары
#
# буймэнкэн киму киммоттан
# бую мэнкан кимот кимотэн
#
# чэлэдур дёлудатан кхобаларчаректор бэргэл бидэтэн
# чэлэдур дялудатын кобаларчар ӈул гяки тар бэргэн бидэтын
#
# тар тку тугеникэн илэ бидэн
# тар тку тугэни кэнели бидин
#
# нуллэ дюдюллэ чалбангавур мэнни эчиддётту
# нэлкэдултк дулэ чалбан гор мынычидёту
#
# чургудау бидээл
# чургудэ бидэн
#
# дондас
# донда
#
# коятчоттэ
# коячоты
#
# чургуридун бидэн
# чургудыдэн бидан
#
# тару онаддин нанкалтыддин
# тар ун оныдинан калтыдин
#
# нан тар онаддинда
# нан тар оныдинда
#
# нан укэлгичиддин
# нан укылгичидин
#
# боктолӈу уӈдэиту
# пактылӈу уӈдэйты
#
# дылӈам уӈ одайи тара
# дылӈам ун кодаитыр
#
# геки там асипара гору уӈэддын
# гэки там ашапар гору уӈыдин
#
# пака покталӈивундин коеӈгэн
# пака пактылӈы уӈыдин коеӈэн
#
# овӈалаӈкан уӈаддиӈнэ
# авыӈэланӈан уӈыдин
#
# тэдэм уӈэдын чэлэв дюрбаткикам очиддын
# тэдэм уӈыдин чэла дюрбы аткикам очидин
#
# нан гяки тар оняддин тар
# нян гэкив тар онадин тар
#
# мэндэчэ тар уӈдин эйду
# мэндэч тар уӈдин эйду
#
# илкэддин энӈэнди тар он тэгэтчэнни туркиду
# илкэдин ынӈынди тар он тыгычин туркиду
#
# мандач уӈдин
# мэндэч уӈдин
#
# ольнар эмнин мунтэки
# олнар ымнин мунтаки
#
# нян
# нан
#
# уклэсиндидэвркимуддывун
# уклэшындидавыр кимутдывун
#
# таду дебэддывун илуддивун
# нан дибэдывун илюдывун
#
# та нюсиддывун т лэский нанта кучуван боривун
# тар нюшэдывун толяшки нан кучуван буривун
#
# нан ӈидыч кояри оннату ноӈан д эсчисхынэн
# нан ӈидэ эч кояр он ноӈан дышчишнин
#
# бадика мэладду
# бадыкар мэладу
#
# ноӈанда мял счиддан хэду дыламда улакча
# ноӈанда мэлашчидын эйду дыл дылан ды улакча
#
# мэргачим хями будю эрэк эчин улак улапча ноӈанан
# мэргэчидын ямибэди экыч улак[unk] улапча ноӈан
#
# улгимин
# улгимидэ
#
# ями эрэки улакча бихэнни
# ями эрэк и улакча бишыни
#
# экчэ
# экчэ
#
# экичирар туркриву онучуклэводастэ бодэлдэгдэ гиллаллини ӈэнюллиндэн
# экичи ирар туркуриву оныч уклэводыш будэлюгда гилалин иӈэнылин
#
# онас уклэрис
# оныш уклэриш
#
# мукчуда оӈала ирив дылдин
# мукчудулан ириву дылди
#
# тытел айич кусчиритэн оралба
# тытэл аич кушчиритын оралбы
#
# агдыл кусчимӈэл
# ы агдыл кушчимӈыл
#
# айич кусчиритэн оралбу
# аич кушчиритын оралбы
#
# тумуюн тумуён это когда олени забют на питание
# тумоён тумоён это кагда аленя забьют на питанье
#
# тумуён
# тумоён
#
# орон исчон эстэн улэвэттэ
# оран ишон эштын улэвэты
#
# нян чэлэвэн чаккоттэ
# нан чэлэвэн чакоты
#
# оилгавур истукэйду аӈаннотта
# ойылгывыр иштук эйду аӈаноты
#
# оралбу
# оралбы
#
# гякич эчин
# гиакич ычин
#
# гиркаснотта орал малтыватта
# гиркашноты орыл малту малтываты
#
# нинх орон
# ну и орыл
#
# нёнакатантар
# нёныкытын
#
# тоже иркашноты ноӈартан мучуватта
# тожи иркашноты ноӈартын мучуваты
#
# а тыкэ тыккэнелит пастухра
# а тык тык кэнели пастух ужэ
#
# молодеж бар банила
# мыладёж бар баныл
#
# кэнелэчэ оролб бхэйду ойритан испорчили
# кэнелидь оралбы эйду ойиритын испортили
#
# бадакар мэёллотта тогу гулуддётта
# бадыкар миалоту тогу гулыдёту
#
# молэддёттыли
# моладётыли
#
# кубуку
# кубыку
#
# амовук уютыддёттука за
# мув уючэд уютыдёту как жэ
#
# илуддэ бадикар аймакан илуддётту нан тара куснадиру
# илюду бадыкар аймакан илюдёту нан тар кушнэдиру
#
# ӈэниддёттув явчимӈал
# ӈынэдёту явчимӈыл
#
# илэккэ явчимӈал бидётту тар тала ӈэнэддётту
# илэк явчимӈыл бидёты тар тала ӈынэдёту
#
# нан явчиӈал дютки уриддир боре кусчиддиру
# нан явчимӈыл дютки урыдир бу жы кушчидиру
#
# нан обед одилливук илбэддётту дютки ӈэнуватт оралбу
# нан обэд одилывык илбэдёту дютки ӈэнувату оралбы
#
# яв д уӈаиддёотта бэдэддётта
# явда уӈыдёту бэлэдёту
#
# итмандиддётту нимутту гунтутэн унаддётта
# итмандидёту нэмэтылбы унадёту
#
# нан тар кускэснаваттэ оймукан оралбу колатаддиру
# нан тар куш кушнавату аймакэн мо оролбы колутыдиру
#
# каич кушутиддавар
# аич кушчидэвыр
#
# укчибисэкэнд илэдэ имӈэнтэки ӈунувэтту амӈичиддётту
# укчи бишикэн илэдэ имӈынтаки ӈэнувату амӈичидёту
#
# нан илэдэ нандак усчиддётту
# нан илэдэ нандэ кушчидёту
#
# нанда молэ ӈэн уватэ колатыдды ораич
# нанда молэ ӈэнувату колутыдавыр аич
#
# нан да илэ дэ имӈэнтэки ӈэнэддёттэ
# нанда илэдэ имӈынтаки ӈынэдёту
#
# челэвуюнуӈунан гиркочиддётту орал долатан
# чэлаву иӈэну гиркавачидёту орал долатын
#
# нан илэдэ гулдэматчоттэ халачиддюр явчимӈалбу
# нан илэдэ гулдымачоту алачидир явчимӈылбы
#
# нан ислиддыв ноӈартан эмуддёттэ нан бдюткиврэдду
# нан ишэлэду ноӈартан ымыдёты нан бу дютки урыды
#
# этикэн гонин тара
# этыкын гунин тырыв
#
# ортаки гэнидэм битчиснэн кобалаккам көчэллэк
# ортыки ӈэнми ичышнын кобалакам кочэлэк
#
# уликэн эгдем
# улыкын эгдэм
#
# маӈӈасан икутычэ
# маӈашын икутыч
#
# элэбу дёралбу дак чакчас эсимэкэт
# элэбэди оралбы чак чакчиш эшэмыкыт
#
# бу нан коечиддэ
# бу нан коечидивун
#
# иттивун кобалам нан эчивун ноӈман мара
# итывун кобалам нан эчивун ноӈман мар
#
# таргу ӈун маский эмэддип тар  маддип
# гунивун амашки эмыдип тар мадип
#
# уту муйоддип ором нэкти нэкригчэн
# тумуедип орам ныктык ныкырывдын
#
# амаски ӈэнэдду ноӈан ачча
# амашки ӈыныду ноӈан ача
#
# илэуттэс оррин
# илэ уты урин
#
# нан тэлэӈниву тыкэнтэки
# нан тэлэӈниву этыкэнтэки
#
# нан мунтэк иркалддаси нэйиндэикутт
# нан мунтаки иркыдын жэ нэидын иркун
